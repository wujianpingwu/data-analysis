# %% [markdown]
# # <center>**第8章**</center>
# - <center>matplotlib API入门</center>
# - <center>pandas的绘图函数</center>
# - <center>绘制地图：图形化显示海地地震危机数据</center>
# - <center>python图形化工具生态系统</center>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt  #为什么不是pylab工具

# %%
plt.plot(np.arange(10))

# %%
#matplotlib API函数（如plot close）都位于matplotlib.pyplot模块中

# %% [markdown]
# **Figure和 Subplot**

# %%
#创建一个新的Figure对象。
fig = plt.figure()

# %%
#matplotlib中的编号架构:plt.figure(1),通过plt.gcf（）即可得到当前的引用过。

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.show()

# %%
from numpy.random import  randn

# %%
plt.plot(randn(50).cumsum(),'k--')

# %%
_ = ax1.hist(randn(100),bins =20,color='k',alpha=0.3)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3 * randn(30))

# %%
#由于根据特定的布局，创建Figure和Subplot是一件非常常见的任务，于是便出现了一个更为简便的方法：**plt.subplots()**,
#返回一个含有已创建suplot对象的Numpy数组

# %%
fig,axes = plt.subplots(2,3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D7753D2160>,
# ...
#       dtype=object)

# %%
#通过sharex或者sharey制定suplot应该具有相同的x轴或者y轴，在比较相同范围的数据时，这也是非常有用。

# %% [markdown]
# **pyplot.subplots的选项**
# 1.nrow subplot行数
# 2.ncols subplot列数
# 3.sharex 所有subplot应该使用相同x轴的刻度
# 4.subplot_kw 用于创建各subplot的关键字字典
# 5.**fig_kw 创建时其他关键字

# %%
#fig,axes和循环要放在同行，plt才能show
fig,axes = plt.subplots(2,2,sharex = True,sharey = True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color='k',alpha=.5)
plt.subplots_adjust(wspace=0,hspace=0)

# %% [markdown]
# **颜色、标记和线型**

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
#更为明确的写法
plt.plot(randn(30).cumsum(),color='k',linestyle = 'dashed',marker='o')

# %% [markdown]
# **刻度、标签和图例**

# %%
plt.xlim()
# Out:
# (0.0, 1.0)

# %%
plt.xlim(0,10)
# Out:
# (0, 10)

# %%
ax3.get_xlim()
# Out:
# (0.0, 1.0)

# %%
ax3.set_xlim(0,10)
# Out:
# (0, 10)

# %% [markdown]
# **设置标题、轴标签、刻度以及刻度标签**

# %%
fig = plt.figure();ax = fig.add_subplot(1,1,1)
ax.plot(randn(10).cumsum())

# %% [markdown]
# **添加图例**

# %%
fig = plt.figure();ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='there')
ax.legend(loc = 'best')
ax.set_title('my first matplotlib plot')
# Out:
# Text(0.5,1,'my first matplotlib plot')

# %% [markdown]
# **注解以及在Subplot上绘图**
